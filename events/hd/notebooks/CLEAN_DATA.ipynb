# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_colwidth", 1000)

# %%
import data_load
reload(data_load)
df_products =  data_load.get_combined()

# %%
import text_parsing
reload(text_parsing)
from text_parsing import str_stem

# %%
df_products
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     queries  \
# product_uid
# ...

# %%
df_products['product_title'] = df_products['product_title'].apply(str_stem)
df_products
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     queries  \
# product_uid
# ...
