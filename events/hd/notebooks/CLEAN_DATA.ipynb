# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_colwidth", 1000)

# %%
import data_load
reload(data_load)
df_products = data_load.get_combined_clean_tokenized()

# %%
import data_load
reload(data_load)
data_load.clean_tokenize_text()

# %%
df_products
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     queries  \
# product_uid
# ...

# %%
df_products_c
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  queries  \
# product_uid
# ...

# %%
df_products2 = data_load.get_combined_clean_tokenized()
df_products2
