# %%
import numpy as np
import pandas as pd

# %%
#LOC = '/home/ec2-user/data/hd/unpacked/'
LOC = '/Users/rbekbolatov/data/kaggle/homedepot/'

df_train = pd.read_csv(LOC + 'train.csv', encoding="ISO-8859-1", index_col='id')
df_test = pd.read_csv(LOC + 'test.csv', encoding="ISO-8859-1", index_col='id')

num_train = df_train.shape[0]
df_train_test = df_train.append(df_test)


df_pro_desc = pd.read_csv(LOC + 'product_descriptions.csv', encoding="ISO-8859-1", index_col='product_uid', dtype={'product_uid': np.int32})


df_attr = pd.read_csv(LOC + 'attributes.csv', encoding="ISO-8859-1")
df_attr = df_attr[df_attr['product_uid'].notnull()]
df_attr['product_uid'] = df_attr['product_uid'].astype(np.int32)
#df_attr = df_attr.groupby('product_uid').agg({'attrs': lambda x: x.to_dict()})
#df_attr.set_index('product_uid', inplace=True)
#, dtype={'product_uid': np.int32})

#df_matches = pd.read_csv(LOC + 'matched_strings_clean.csv').fillna("")

#df_brand = df_attr[df_attr.name == "MFG Brand Name"][["product_uid", "value"]].rename(columns={"value": "brand"}).fillna("NONE")

# %%
a = { product_uid: group.set_index('name')['value'].to_dict() for product_uid, group in df_attr.groupby('product_uid')}

# %%
b = pd.DataFrame(a).T
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-6d4930f9bd86> in <module>()
# ----> 1 b = pd.DataFrame(a).T
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in transpose(self)
#    1772     def transpose(self):
#    1773         """Transpose index and columns"""
# -> 1774         return super(DataFrame, self).transpose(1, 0)
#    1775
#    1776     T = property(transpose)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in transpose(self, *args, **kwargs)
#     471                             'argument "{0}"'.format(list(kwargs.keys())[0]))
#     472
# --> 473         return self._constructor(new_values, **new_axes).__finalize__(self)
#     474
#     475     def swapaxes(self, axis1, axis2, copy=True):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
# ...

# %%
df_train_test
# Out:
#                                             product_title  product_uid  \
# id
# 2                       Simpson Strong-Tie 12-Gauge Angle       100001
# 3                       Simpson Strong-Tie 12-Gauge Angle       100001
# 9       BEHR Premium Textured DeckOver 1-gal. #SC-141 ...       100002
# 16      Delta Vero 1-Handle Shower Only Faucet Trim Ki...       100005
# 17      Delta Vero 1-Handle Shower Only Faucet Trim Ki...       100005
# 18      Whirlpool 1.9 cu. ft. Over the Range Convectio...       100006
# 20      Whirlpool 1.9 cu. ft. Over the Range Convectio...       100006
# 21      Whirlpool 1.9 cu. ft. Over the Range Convectio...       100006
# 23      Lithonia Lighting Quantum 2-Light Black LED Em...       100007
# 27      House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...       100009
# 34           Valley View Industries Metal Stakes (4-Pack)       100010
# 35      Toro Personal Pace Recycler 22 in. Variable Sp...       100011
# ...

# %%
a[100001]
# Out:
# {u'Bullet01': u'Versatile connector for various 90\xc2\xb0 connections and home repair projects',
#  u'Bullet02': u'Stronger than angled nailing or screw fastening alone',
#  u'Bullet03': u'Help ensure joints are consistently straight and strong',
#  u'Bullet04': u'Dimensions: 3 in. x 3 in. x 1-1/2 in.',
#  u'Bullet05': u'Made from 12-Gauge steel',
#  u'Bullet06': u'Galvanized for extra corrosion resistance',
#  u'Bullet07': u'Install with 10d common nails or #9 x 1-1/2 in. Strong-Drive SD screws',
#  u'Gauge': u'12',
#  u'MFG Brand Name': u'Simpson Strong-Tie',
#  u'Material': u'Galvanized Steel',
#  u'Number of Pieces': u'1',
#  u'Product Depth (in.)': u'1.5',
#  u'Product Height (in.)': u'3',
#  u'Product Weight (lb.)': u'0.26',
#  u'Product Width (in.)': u'3'}

# %%
np.int32

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-5f9bb20e20e1> in <module>()
# ----> 1 df_train_test = df_train.append(df_test).set_index('id', inplace=True)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2829                 names.append(None)
#    2830             else:
# -> 2831                 level = frame[col]._values
#    2832                 names.append(col)
#    2833                 if drop:
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# ...

# %%
df_train_test
# Out:
#             id                                      product_title  \
# 0            2                  Simpson Strong-Tie 12-Gauge Angle
# 1            3                  Simpson Strong-Tie 12-Gauge Angle
# 2            9  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3           16  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4           17  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 5           18  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 6           20  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 7           21  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 8           23  Lithonia Lighting Quantum 2-Light Black LED Em...
# 9           27  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 10          34       Valley View Industries Metal Stakes (4-Pack)
# 11          35  Toro Personal Pace Recycler 22 in. Variable Sp...
# 12          37  Toro Personal Pace Recycler 22 in. Variable Sp...
# ...

# %%
# Out:
#                                             product_title  product_uid  \
# id
# 2                       Simpson Strong-Tie 12-Gauge Angle       100001
# 3                       Simpson Strong-Tie 12-Gauge Angle       100001
# 9       BEHR Premium Textured DeckOver 1-gal. #SC-141 ...       100002
# 16      Delta Vero 1-Handle Shower Only Faucet Trim Ki...       100005
# 17      Delta Vero 1-Handle Shower Only Faucet Trim Ki...       100005
# 18      Whirlpool 1.9 cu. ft. Over the Range Convectio...       100006
# 20      Whirlpool 1.9 cu. ft. Over the Range Convectio...       100006
# 21      Whirlpool 1.9 cu. ft. Over the Range Convectio...       100006
# 23      Lithonia Lighting Quantum 2-Light Black LED Em...       100007
# 27      House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...       100009
# 34           Valley View Industries Metal Stakes (4-Pack)       100010
# 35      Toro Personal Pace Recycler 22 in. Variable Sp...       100011
# ...
