# %%
import time
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
#from sklearn import pipeline, model_selection
from sklearn import pipeline, grid_search
#from sklearn.feature_extraction import DictVectorizer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import FeatureUnion
from sklearn.decomposition import TruncatedSVD
#from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import mean_squared_error, make_scorer
#from nltk.metrics import edit_distance


#from nltk.stem.porter import *
#stemmer = PorterStemmer()

##from nltk.stem.snowball import SnowballStemmer #0.003 improvement but takes twice as long as PorterStemmer
##stemmer = SnowballStemmer('english')

import re
#import enchant
import random
random.seed(2016)

# %%
LOC = '/Users/rbekbolatov/data/kaggle/homedepot/'
df_train = pd.read_csv(LOC + 'train.csv', encoding="ISO-8859-1")
df_test = pd.read_csv(LOC + 'test.csv', encoding="ISO-8859-1")
df_pro_desc = pd.read_csv(LOC + 'product_descriptions.csv')
df_attr = pd.read_csv(LOC + 'attributes.csv')
df_matches = pd.read_csv(LOC + 'matched_strings_clean.csv')

df_brand = df_attr[df_attr.name == "MFG Brand Name"][["product_uid", "value"]].rename(columns={"value": "brand"})
num_train = df_train.shape[0]
# (74067, 5), (166693, 4) -> df_train.shape, df_test.shape

# %%
df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True) # (240760, 5)
df_all = pd.merge(df_all, df_pro_desc, how='left', on='product_uid')
df_all = pd.merge(df_all, df_brand, how='left', on='product_uid')
df_all = pd.merge(df_all, df_matches, on='id')

# %%
df_all
# Out:
#             id                                      product_title  \
# 0            2                  Simpson Strong-Tie 12-Gauge Angle
# 1            3                  Simpson Strong-Tie 12-Gauge Angle
# 2            9  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3           16  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4           17  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 5           18  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 6           20  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 7           21  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 8           23  Lithonia Lighting Quantum 2-Light Black LED Em...
# 9           27  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 10          34       Valley View Industries Metal Stakes (4-Pack)
# 11          35  Toro Personal Pace Recycler 22 in. Variable Sp...
# 12          37  Toro Personal Pace Recycler 22 in. Variable Sp...
# 13          38  Toro Personal Pace Recycler 22 in. Variable Sp...
# 14          48  Hampton Bay Caramel Simple Weave Bamboo Rollup...
# 15          51  InSinkErator SinkTop Switch Single Outlet for ...
# 16          65  Sunjoy Calais 8 ft. x 5 ft. x 8 ft. Steel Tile...
# 17          69  MD Building Products 36 in. x 36 in. Cloverlea...
# 18          75  MD Building Products 36 in. x 36 in. Cloverlea...
# 19          81  MD Building Products 36 in. x 36 in. Cloverlea...
# 20          85  MD Building Products 36 in. x 36 in. Cloverlea...
# 21          88  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 22          90  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 23          92  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 24         101  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 25         105  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 26         106  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 27         113  1804 Dual Spray Half Pattern 4 in Pop-Up Spray...
# 28         114  1804 Dual Spray Half Pattern 4 in Pop-Up Spray...
# 29         117  Samsung 4.2 cu. ft. Front Load Washer with Ste...
# ...        ...                                                ...
# 240730  240731                      6-Panel Composite Bifold Door
# 240731  240732     Eaton CSR 200-Amp Double Pole Main Breaker Kit
# 240732  240733  Crown Bolt 3/16 in. Zinc Plated Steel Axle Hat...
# 240733  240734              Dickies 2-Pocket Utility Knife Sheath
# 240734  240735  Patio Living Concepts San Juan 60 in. Outdoor ...
# 240735  240736             Speakman Emergency Eyewash Safety Sign
# 240736  240737      Plantronics Cable for M12 and CS50/CS55 Phone
# 240737  240738  Glomar Vanguard 9-Light Textured Black Chandel...
# 240738  240739        Kwikset Milan Satin Nickel Half-Dummy Lever
# 240739  240740  Advanced Drainage Systems 1/2 in. x 100 ft. IP...
# 240740  240741  Magnavox 50 in. Class LED 1080p 120 BMR Slim HDTV
# 240741  240742  Ekena Millwork 7 in. x 3/4 in. x 11 in. Hillsb...
# 240742  240743  Minwax 1 gal. Semi-Gloss Polycrylic Protective...
# 240743  240744  Southern Living Plant Collection 3 Gal. Pink S...
# 240744  240745  GE 5.0 cu. ft. Gas Range with Self-Cleaning Ov...
# 240745  240746  Southwire 150 ft. 12-3 CU W/G Submersible Pump...
# 240746  240747  Generac Protector Series 15,000-Watt 120/240-V...
# 240747  240748  KOHLER Clearflo Brass Toe Tap Bath Drain in Vi...
# 240748  240749  Casablanca 4-Light Maiden Bronze Ceiling Fan F...
# 240749  240750  Glidden Premium 5-gal. #HDGR19 Fresh Peonies S...
# 240750  240751  Everbilt 1/8 in. x 50 ft. Reflective Black Par...
# 240751  240752  Crown Bolt 5/16 in. (1/4 in.-20) x 1-1/2 in. A...
# 240752  240753  Universal Tubs 4.5 ft. Right Drain Wheel Chair...
# 240753  240754  Everbilt #12 x 1-1/2 in. Phillips Brass Flat-H...
# 240754  240755  Coastal Shower Doors Legend Series 24 in. x 64...
# 240755  240756  stufurhome Norma 24 in. W x 16 in. D x 34 in. ...
# 240756  240757  Home Decorators Collection 49 in. D Alessandro...
# 240757  240758  Simpson Strong-Tie HB 3-1/2 x 14 in. Top Flang...
# 240758  240759  1/4 in. -20 tpi x 1-1/2 in. Stainless Steel Bu...
# 240759  240760                      Bosch 4 in. Bi-Metal Hole Saw
#
#         product_uid  relevance                         search_term  \
# 0            100001       3.00                       angle bracket
# 1            100001       2.50                           l bracket
# 2            100002       3.00                           deck over
# 3            100005       2.33                    rain shower head
# 4            100005       2.67                  shower only faucet
# 5            100006       3.00                      convection otr
# 6            100006       2.67                microwave over stove
# 7            100006       3.00                          microwaves
# 8            100007       2.67                     emergency light
# 9            100009       3.00                             mdf 3/4
# 10           100010       2.67                        steele stake
# 11           100011       3.00      briggs and stratton lawn mower
# 12           100011       3.00                            gas mowe
# 13           100011       2.00                         honda mower
# 14           100012       2.67  hampton bay chestnut pull up shade
# 15           100013       2.67                            disposer
# 16           100016       3.00                        grill gazebo
# 17           100017       1.00                         door guards
# 18           100017       1.67              metal plate cover gcfi
# 19           100017       2.33                      radiator grate
# 20           100017       2.33                     windows screens
# 21           100019       1.33            1x1 rail decorative wood
# 22           100019       2.67              4*8 beadboard paneling
# 23           100019       2.33                    4x8wood paneling
# 24           100019       1.33                             MDF 4x8
# 25           100019       2.33                 wainscot chair rail
# 26           100019       2.33             wainscot plank paneling
# 27           100021       2.00                      lawn sprkinler
# 28           100021       2.33                  rainbird sprinkler
# 29           100022       2.67                PLATFORM FOR WASHERS
# ...             ...        ...                                 ...
# 240730       224399        NaN            bifold oak 6 panel doors
# 240731       224400        NaN         200 amp breaker double pole
# 240732       224401        NaN                   axle locking nuts
# 240733       224402        NaN                              sheath
# 240734       224403        NaN                outdoor patio shades
# 240735       224404        NaN                        safety signs
# 240736       224405        NaN                         phone cable
# 240737       224406        NaN                            vanguard
# 240738       224407        NaN                        dummy handle
# 240739       224408        NaN           Advanced drainage systems
# 240740       224409        NaN                             led tvs
# 240741       224410        NaN                           l molding
# 240742       224411        NaN                   minwax polycrylic
# 240743       224412        NaN                           camellias
# 240744       224413        NaN                    black gas ranges
# 240745       224414        NaN                    submersible wire
# 240746       224415        NaN       32kw generac protector series
# 240747       224416        NaN                       bathroom taps
# 240748       224417        NaN          ceiling fan light fixtures
# 240749       224418        NaN                             Peonies
# 240750       224419        NaN                            paracord
# 240751       224420        NaN                2 inch  1/4-20 bolts
# 240752       224421        NaN                         bath chairs
# 240753       224422        NaN                           1/2 brass
# 240754       224423        NaN                  pivot shower doors
# 240755       224424        NaN            24 whtie storage cabinet
# 240756       224425        NaN                   adirondeck cusion
# 240757       224426        NaN                                  hb
# 240758       224427        NaN                         hex sockets
# 240759       224428        NaN                     4 inch hole saw
#
#                                       product_description  \
# 0       Not only do angles make joints stronger, they ...
# 1       Not only do angles make joints stronger, they ...
# 2       BEHR Premium Textured DECKOVER is an innovativ...
# 3       Update your bathroom with the Delta Vero Singl...
# 4       Update your bathroom with the Delta Vero Singl...
# 5       Achieving delicious results is almost effortle...
# 6       Achieving delicious results is almost effortle...
# 7       Achieving delicious results is almost effortle...
# 8       The Quantum Adjustable 2-Light LED Black Emerg...
# 9       Get the House of Fara 3/4 in. x 3 in. x 8 ft. ...
# 10      Valley View Industries Metal Stakes (4-Pack) a...
# 11      Recycler 22 in. Personal Pace Variable Speed S...
# 12      Recycler 22 in. Personal Pace Variable Speed S...
# 13      Recycler 22 in. Personal Pace Variable Speed S...
# 14      The 96 in. wide Caramel Simple Weave Rollup Ba...
# 15      The InSinkErator SinkTop Switch Single Outlet ...
# 16      Make grilling great with this handsome and fun...
# 17      The MD Building Products 36 in. x 36 in. x 1/5...
# 18      The MD Building Products 36 in. x 36 in. x 1/5...
# 19      The MD Building Products 36 in. x 36 in. x 1/5...
# 20      The MD Building Products 36 in. x 36 in. x 1/5...
# 21      The House of Fara 8 Linear ft. primed MDF Over...
# 22      The House of Fara 8 Linear ft. primed MDF Over...
# 23      The House of Fara 8 Linear ft. primed MDF Over...
# 24      The House of Fara 8 Linear ft. primed MDF Over...
# 25      The House of Fara 8 Linear ft. primed MDF Over...
# 26      The House of Fara 8 Linear ft. primed MDF Over...
# 27      Installed in parks and backyards across the gl...
# 28      Installed in parks and backyards across the gl...
# 29      The Samsung 4.2 cu. ft. Front Load Washer with...
# ...                                                   ...
# 240730  Give your home a custom look with Plantation s...
# 240731  The Eaton CSR 200-Amp Double-Pole Main Breaker...
# 240732  These push nuts have no screw thread but have ...
# 240733  The Dickies Utility Knife Sheath is constructe...
# 240734  Carefree resin durability, while adding elegan...
# 240735  The Speakman branded emergency eyewash safety ...
# 240736  The PL-65111-01 is a Plantronics phone accesso...
# 240737  The 1940's are back with a hint of today. Avai...
# 240738  Step up to designer styles and superior securi...
# 240739  1/2 in. x 100 ft. IPS 125 psi NSF Poly Pipe is...
# 240740  Enjoy optimal viewing areas with the Magnavox ...
# 240741  Beautiful crown moulding is a great way to sep...
# 240742  Minwax Polycrylic Protective Finish is a prote...
# 240743  The Pink Stella Camellia from the Southern Liv...
# 240744  Your GE 30 in. 5.0 cu. ft. Gas Range with Self...
# 240745  Southwires Submersible Pump cable is used subm...
# 240746  Generacs new Protector Series diesel generator...
# 240747  The Clearflo Brass Toe-tap bath drain works pe...
# 240748  The Light Kit by Casablanca is a great design ...
# 240749  The Glidden Premium 5-gal. Satin Latex Exterio...
# 240750  Paracord is ideal for camping, hiking and othe...
# 240751  Crown Bolt's shoulder bolts are also known as ...
# 240752  Wheel Chair Accessible's provide a safe and in...
# 240753  These wood screws are thread forming screws wi...
# 240754  The Legend Series framed swing stand-alone con...
# 240755  Create a neat yet stylish storage space for or...
# 240756  Our Bullnose Adirondack Chair Cushions fit Adi...
# 240757  Joist hangers are designed to provide support ...
# 240758  These socket cap screws are ideal for applicat...
# 240759  The Bosch quick change bi-metal hole saws feat...
#
#                                  brand_x                              tit  \
# 0                     Simpson Strong-Tie                            angle
# 1                     Simpson Strong-Tie                              NaN
# 2         BEHR Premium Textured DeckOver                             deck
# 3                                  Delta                           shower
# 4                                  Delta             shower, only, faucet
# 5                              Whirlpool                       convection
# 6                              Whirlpool                        microwave
# 7                              Whirlpool                        microwave
# 8                      Lithonia Lighting                 emergency, light
# 9                          House of Fara                        mdf, 3, 4
# 10                Valley View Industries                           stakes
# 11                                  Toro    briggs, stratton, lawn, mower
# 12                                  Toro                       gas, mower
# 13                                  Toro                            mower
# 14                           Hampton Bay              bay, shade, hampton
# 15                          InSinkErator                        disposers
# 16                                Sunjoy                    grill, gazebo
# 17                  MD Building Products                              NaN
# 18                  MD Building Products                              NaN
# 19                  MD Building Products                              NaN
# 20                  MD Building Products                              NaN
# 21                         House of Fara                              NaN
# 22                         House of Fara                      8, paneling
# 23                         House of Fara                      8, paneling
# 24                         House of Fara                           mdf, 8
# 25                         House of Fara                         wainscot
# 26                         House of Fara               wainscot, paneling
# 27                             Rain Bird                              NaN
# 28                             Rain Bird                              NaN
# 29                               Samsung                           washer
# ...                                  ...                              ...
# 240730         Home Fashion Technologies           panel, 6, door, bifold
# 240731                             Eaton  breaker, amp, double, pole, 200
# 240732                        Crown Bolt                       axle, nuts
# 240733                           Dickies                           sheath
# 240734             Patio Living Concepts            outdoor, patio, shade
# 240735                          Speakman                     safety, sign
# 240736                       Plantronics                     phone, cable
# 240737                            Glomar                         vanguard
# 240738                           Kwikset                            dummy
# 240739         Advanced Drainage Systems      advanced, drainage, systems
# 240740                          Magnavox                              led
# 240741                    Ekena Millwork                         moulding
# 240742                            Minwax               minwax, polycrylic
# 240743  Southern Living Plant Collection                         camellia
# 240744                                GE                black, gas, range
# 240745                         Southwire                      submersible
# 240746                           Generac       series, generac, protector
# 240747                            KOHLER                              tap
# 240748                        Casablanca     ceiling, fan, light, fixture
# 240749                               NaN                          peonies
# 240750                          Everbilt                         paracord
# 240751                        Crown Bolt          4, inch, bolt, 1, 20, 2
# 240752                    Universal Tubs                      bath, chair
# 240753                          Everbilt                      1, 2, brass
# 240754              Coastal Shower Doors                    shower, doors
# 240755                        stufurhome      24, white, storage, cabinet
# 240756        Home Decorators Collection              adirondack, cushion
# 240757                               NaN                               hb
# 240758                               NaN                      hex, socket
# 240759                             Bosch               4, inch, hole, saw
#
#                                        tit2                             desc  \
# 0                                       NaN                   angled, angles
# 1                                       NaN                              NaN
# 2                                       NaN                             deck
# 3                                       NaN                           shower
# 4                  shower_only, only_faucet             shower, only, faucet
# 5                                       NaN                       convection
# 6                                       NaN                 microwave, smoke
# 7                                       NaN                        microwave
# 8                                       NaN                 emergency, light
# 9                                       3_4                        mdf, 3, 4
# 10                                      NaN            steel, staked, stakes
# 11                               lawn_mower    briggs, stratton, lawn, mower
# 12                                      NaN                       gas, mower
# 13                                      NaN                            mower
# 14                              hampton_bay                  up, shade, pull
# 15                                      NaN                        disposers
# 16                             grill_gazebo                    grill, gazebo
# 17                                      NaN                             door
# 18                                      NaN                              NaN
# 19                                      NaN                              NaN
# 20                                      NaN                  window, screens
# 21                                      NaN                          1, rail
# 22                                      NaN                      8, paneling
# 23                                      NaN                      8, paneling
# 24                                      NaN                           mdf, 8
# 25                                      NaN            wainscot, chair, rail
# 26                                      NaN               wainscot, paneling
# 27                                      NaN                  lawn, sprinkler
# 28                                      NaN                        sprinkler
# 29                                      NaN                          washers
# ...                                     ...                              ...
# 240730                              6_panel            doors, panel, 6, fold
# 240731                 200_amp, double_pole  breaker, amp, double, pole, 200
# 240732                                  NaN                             nuts
# 240733                                  NaN                           sheath
# 240734                                  NaN                   outdoor, shade
# 240735                          safety_sign                    safety, signs
# 240736                                  NaN                     phone, cable
# 240737                                  NaN                         vanguard
# 240738                                  NaN                    dummy, handed
# 240739  advanced_drainage, drainage_systems                              NaN
# 240740                                  NaN                              led
# 240741                                  NaN                         moulding
# 240742                                  NaN               minwax, polycrylic
# 240743                                  NaN                        camellias
# 240744                            gas_range                black, gas, range
# 240745                                  NaN                      submersible
# 240746  generac_protector, protector_series       series, generac, protector
# 240747                                  NaN                    bathroom, tap
# 240748                          ceiling_fan              ceiling, fan, light
# 240749                                  NaN                              NaN
# 240750                                  NaN                         paracord
# 240751                  inch_1, 2_inch, 1_4                   inch, 1, bolts
# 240752                                  NaN                            chair
# 240753                                  1_2                      1, 2, brass
# 240754                         shower_doors                     shower, door
# 240755                                  NaN      24, white, storage, cabinet
# 240756                                  NaN              adirondack, cushion
# 240757                                  NaN                               hb
# 240758                           hex_socket                      hex, socket
# 240759                     4_inch, hole_saw                       inch, hole
#
#                                        desc2                             attr  \
# 0                                        NaN                           angled
# 1                                        NaN                              NaN
# 2                                        NaN                             deck
# 3                                        NaN                     rain, shower
# 4                                        NaN             shower, only, faucet
# 5                                        NaN                       convection
# 6                                        NaN          microwave, smoke, style
# 7                                        NaN                        microwave
# 8                                        NaN                 emergency, light
# 9                                        3_4                           mdf, 3
# 10                              steel_stakes                    steel, stakes
# 11               briggs_stratton, lawn_mower    briggs, stratton, lawn, mower
# 12                                       NaN                       gas, mower
# 13                                       NaN                            mower
# 14                                   roll_up    bay, up, shade, hampton, pull
# 15                                       NaN                        disposers
# 16                              grill_gazebo                    grill, gazebo
# 17                                       NaN                             door
# 18                                       NaN                            metal
# 19                                       NaN                              NaN
# 20                            window_screens                  window, screens
# 21                                       NaN                          1, rail
# 22                                       NaN           beadboard, 8, paneling
# 23                                    8_foot                      8, paneling
# 24                                       NaN                           mdf, 8
# 25                wainscot_chair, chair_rail            wainscot, chair, rail
# 26                                       NaN               wainscot, paneling
# 27                                       NaN                        sprinkler
# 28                                       NaN                        sprinkler
# 29                                       NaN                           washer
# ...                                      ...                              ...
# 240730                               6_panel        panel, door, fold, 6, oak
# 240731                  200_amp, double_pole  breaker, amp, double, pole, 200
# 240732                                   NaN                        axle, nut
# 240733                                   NaN                              NaN
# 240734                                   NaN            outdoor, patio, shade
# 240735                          safety_signs                    safety, signs
# 240736                                   NaN                            cable
# 240737                                   NaN                              NaN
# 240738                                   NaN                    dummy, handed
# 240739                                   NaN      advanced, drainage, systems
# 240740                                   NaN                              led
# 240741                                   NaN                         moulding
# 240742                     minwax_polycrylic                           minwax
# 240743                                   NaN                         camellia
# 240744                             gas_range                black, gas, range
# 240745                                   NaN                             wire
# 240746  generacs_protector, protector_series       series, generac, protector
# 240747                                   NaN                              tap
# 240748                ceiling_fan, fan_light              ceiling, fan, light
# 240749                                   NaN                              NaN
# 240750                                   NaN                         paracord
# 240751                                   NaN              4, inch, bolt, 1, 2
# 240752                                   NaN                             bath
# 240753                                   1_2                      1, 2, brass
# 240754                           shower_door                    shower, doors
# 240755                                   NaN                        24, white
# 240756                                   NaN                          cushion
# 240757                                   NaN                              NaN
# 240758                                   NaN                              NaN
# 240759                             hole_saws               4, inch, hole, saw
#
#                             brand_y                               brand2
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                              deck                                  NaN
# 3                               NaN                                  NaN
# 4                               NaN                                  NaN
# 5                               NaN                                  NaN
# 6                               NaN                                  NaN
# 7                               NaN                                  NaN
# 8                               NaN                                  NaN
# 9                               NaN                                  NaN
# 10                              NaN                                  NaN
# 11                              NaN                                  NaN
# 12                              NaN                                  NaN
# 13                              NaN                                  NaN
# 14                     bay, hampton                          hampton_bay
# 15                              NaN                                  NaN
# 16                              NaN                                  NaN
# 17                              NaN                                  NaN
# 18                              NaN                                  NaN
# 19                              NaN                                  NaN
# 20                              NaN                                  NaN
# 21                              NaN                                  NaN
# 22                              NaN                                  NaN
# 23                              NaN                                  NaN
# 24                              NaN                                  NaN
# 25                              NaN                                  NaN
# 26                              NaN                                  NaN
# 27                              NaN                                  NaN
# 28                              NaN                                  NaN
# 29                              NaN                                  NaN
# ...                             ...                                  ...
# 240730                          NaN                                  NaN
# 240731                          NaN                                  NaN
# 240732                          NaN                                  NaN
# 240733                          NaN                                  NaN
# 240734                        patio                                  NaN
# 240735                          NaN                                  NaN
# 240736                          NaN                                  NaN
# 240737                          NaN                                  NaN
# 240738                          NaN                                  NaN
# 240739  advanced, drainage, systems  advanced_drainage, drainage_systems
# 240740                          NaN                                  NaN
# 240741                          NaN                                  NaN
# 240742                       minwax                                  NaN
# 240743                          NaN                                  NaN
# 240744                          NaN                                  NaN
# 240745                          NaN                                  NaN
# 240746                      generac                                  NaN
# 240747                          NaN                                  NaN
# 240748                          NaN                                  NaN
# 240749                          NaN                                  NaN
# 240750                          NaN                                  NaN
# 240751                         bolt                                  NaN
# 240752                          NaN                                  NaN
# 240753                          NaN                                  NaN
# 240754                shower, doors                         shower_doors
# 240755                          NaN                                  NaN
# 240756                          NaN                                  NaN
# 240757                          NaN                                  NaN
# 240758                          NaN                                  NaN
# 240759                          NaN                                  NaN
#
# [240760 rows x 14 columns]

# %%
df_all[df_all.product_uid == 131446]

# %%
# 4x2
XBY = "xby"
pattern_xby_d = re.compile(r"(x[0-9])")
pattern_d_xby = re.compile(r"([0-9])x")

# units
pattern_inch = re.compile(r"([0-9])( *)(inches|inch|in|')\.?")
pattern_foot = re.compile(r"([0-9])( *)(foot|feet|ft|''|\")\.?")
pattern_pound = re.compile(r"([0-9])( *)(pounds|pound|lbs|lb)\.?")
pattern_sqft = re.compile(r"([0-9])( *)(square|sq) ?\.?(feet|foot|ft)\.?")
pattern_gallons = re.compile(r"([0-9])( *)(gallons|gallon|gal)\.?")
pattern_oz = re.compile(r"([0-9])( *)(ounces|ounce|oz)\.?")
pattern_cm = re.compile(r"([0-9])( *)(centimeters|cm)\.?")
pattern_mm = re.compile(r"([0-9])( *)(milimeters|mm)\.?")
pattern_deg = re.compile(r"([0-9])( *)(degrees|degree)\.?")
pattern_volt = re.compile(r"([0-9])( *)(volts|volt)\.?")
pattern_watt = re.compile(r"([0-9])( *)(watts|watt)\.?")
pattern_amp = re.compile(r"([0-9])( *)(amperes|ampere|amps|amp)\.?")

# split
pattern_split = re.compile('[^0-9a-z]')

def str_stem(s): 
    if isinstance(s, str) or isinstance(s, unicode):
        s = s.lower().strip()
        
        # 4ft x 2ft
        s = s.replace(" x "," " + XBY + " ")
        s = s.replace("*"," " + XBY + " ")        
        s = s.replace(" by "," " + XBY)
        s = pattern_xby_d.sub(" " + XBY + " \1", s)
        s = pattern_d_xby.sub("\1 " + XBY + " ", s)
        
        # units
        s = pattern_inch.sub(r"\1 inch ", s)
        s = pattern_foot.sub(r"\1 foot ", s)
        s = pattern_pound.sub(r"\1 pound ", s)
        s = pattern_sqft.sub(r"\1 sqft ", s)
        s = pattern_gallons.sub(r"\1 gal ", s)
        s = pattern_oz.sub(r"\1 oz ", s)
        s = pattern_cm.sub(r"\1 cm ", s)
        s = pattern_mm.sub(r"\1 mm ", s)
        s = pattern_deg.sub(r"\1 deg ", s)
        s = pattern_volt.sub(r"\1 volt ", s)
        s = pattern_watt.sub(r"\1 watt ", s)
        s = pattern_amp.sub(r"\1 amp ", s)
        
        # some by hand
        s = s.replace("whirpool","whirlpool")
        s = s.replace("whirlpoolga", "whirlpool")
        s = s.replace("whirlpoolstainless","whirlpool stainless")
        
        s = ' '.join([x for x in pattern_split.split(s) if x])
        return s
    else:
        raise ValueError("Type of " + str(s) + " is " + str(type(s)))
        print "HUY"
        return 'null'

# %%
df_all[df_all['brand'].isnull()]

# %%
df_all['search_term'] = df_all['search_term'].map(lambda x:str_stem(x))
df_all['product_title'] = df_all['product_title'].map(lambda x:str_stem(x))
df_all['product_description'] = df_all['product_description'].map(lambda x:str_stem(x))
df_all['brand'] = df_all['brand'].map(lambda x:str_stem(x))

# %%
def str_common_word(str1, str2):
    words, cnt = str1.split(), 0
    for word in words:
        if str2.find(word)>=0:
            cnt+=1
    return cnt

def str_whole_word(str1, str2, i_):
    cnt = 0
    while i_ < len(str2):
        i_ = str2.find(str1, i_)
        if i_ == -1:
            return cnt
        else:
            cnt += 1
            i_ += len(str1)
    return cnt

# id	product_title	product_uid	relevance	search_term	product_description	brand
# id, relevance, search_term, product_title, product_description, (product_uid,) brand  [product_info, attr]
class cust_regression_vals(BaseEstimator, TransformerMixin):
    def fit(self, x, y=None):
        return self
    def transform(self, hd_searches):
        d_col_drops=['id','relevance','search_term','product_title','product_description','product_info','attr','brand']
        hd_searches = hd_searches.drop(d_col_drops,axis=1).values
        return hd_searches

class cust_txt_col(BaseEstimator, TransformerMixin):
    def __init__(self, key):
        self.key = key
    def fit(self, x, y=None):
        return self
    def transform(self, data_dict):
        return data_dict[self.key].apply(str)

def fmean_squared_error(ground_truth, predictions):
    fmean_squared_error_ = mean_squared_error(ground_truth, predictions)**0.5
    return fmean_squared_error_

RMSE  = make_scorer(fmean_squared_error, greater_is_better=False)

# %%
start_time = time.time()

#comment out the lines below use df_all.csv for further grid search testing
#if adding features consider any drops on the 'cust_regression_vals' class

df_all['product_info'] = df_all['search_term']+"\t"+df_all['product_title'] +"\t"+df_all['product_description']
df_all['attr'] = df_all['search_term']+"\t"+df_all['brand']

df_all['len_of_query'] = df_all['search_term'].map(lambda x:len(x.split())).astype(np.int64)
df_all['len_of_title'] = df_all['product_title'].map(lambda x:len(x.split())).astype(np.int64)
df_all['len_of_description'] = df_all['product_description'].map(lambda x:len(x.split())).astype(np.int64)
df_all['len_of_brand'] = df_all['brand'].map(lambda x:len(x.split())).astype(np.int64)
df_all['query_in_title'] = df_all['product_info'].map(lambda x:str_whole_word(x.split('\t')[0],x.split('\t')[1],0))
df_all['query_in_description'] = df_all['product_info'].map(lambda x:str_whole_word(x.split('\t')[0],x.split('\t')[2],0))
df_all['word_in_title'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[1]))
df_all['word_in_description'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[2]))
df_all['ratio_title'] = df_all['word_in_title']/df_all['len_of_query']
df_all['ratio_description'] = df_all['word_in_description']/df_all['len_of_query']
df_all['word_in_brand'] = df_all['attr'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[1]))
df_all['ratio_brand'] = df_all['word_in_brand']/df_all['len_of_brand']

df_brand = pd.unique(df_all.brand.ravel())
d={}
i = 1
for s in df_brand:
    d[s]=i
    i+=1
df_all['brand_feature'] = df_all['brand'].map(lambda x:d[x])
df_all['search_term_feature'] = df_all['search_term'].map(lambda x:len(x))

df_all.to_csv('df_all.csv')
#df_all = pd.read_csv('df_all.csv', encoding="ISO-8859-1", index_col=0)

df_train = df_all.iloc[:num_train]
df_test = df_all.iloc[num_train:]
id_test = df_test['id']
y_train = df_train['relevance'].values
X_train = df_train[:]
X_test = df_test[:]
print("--- Features Set: %s minutes ---" % round(((time.time() - start_time)/60), 2))

# %%
# LOAD FROM SAVED
df_all = pd.read_csv('df_all.csv', encoding="ISO-8859-1", index_col=0)

df_train = df_all.iloc[:num_train]
df_test = df_all.iloc[num_train:]
id_test = df_test['id']
y_train = df_train['relevance'].values
X_train = df_train[:]
X_test = df_test[:]

# %%
df_all[300:320][['relevance', 'product_title', 'search_term', 'product_description']]

# %%
X_train.columns

# %%
tfidf = TfidfVectorizer(ngram_range=(1, 1), stop_words='english')
#tsvd = TruncatedSVD(n_components=10, random_state = 2016)
rfr = RandomForestRegressor(n_estimators = 500, n_jobs = -1, random_state = 2016, verbose = 1)

clf = pipeline.Pipeline([
        ('union', FeatureUnion(
                    transformer_list = [
                        ('cst',  cust_regression_vals()),  
                    
#                         ('txt1', pipeline.Pipeline([('s1', cust_txt_col(key='search_term')), ('tfidf1', tfidf), ('tsvd1', tsvd)])),
#                         ('txt2', pipeline.Pipeline([('s2', cust_txt_col(key='product_title')), ('tfidf2', tfidf), ('tsvd2', tsvd)])),
#                         ('txt3', pipeline.Pipeline([('s3', cust_txt_col(key='product_description')), ('tfidf3', tfidf), ('tsvd3', tsvd)])),
#                         ('txt4', pipeline.Pipeline([('s4', cust_txt_col(key='brand')), ('tfidf4', tfidf), ('tsvd4', tsvd)]))
                    
                        ('txt1', pipeline.Pipeline([ ('s1', cust_txt_col(key='search_term')), ('tfidf1', tfidf)  ])),
                        ('txt2', pipeline.Pipeline([ ('s2', cust_txt_col(key='product_title')), ('tfidf2', tfidf)  ])),
                        ('txt3', pipeline.Pipeline([ ('s3', cust_txt_col(key='product_description')), ('tfidf3', tfidf) ])),
                        ('txt4', pipeline.Pipeline([ ('s4', cust_txt_col(key='brand')), ('tfidf4', tfidf) ]))
                    
                        ],
                    transformer_weights = {
                        'cst': 1.0,
                        'txt1': 0.5,
                        'txt2': 0.25,
                        'txt3': 0.0,
                        'txt4': 0.5
                        },
                n_jobs = -1
                )), 
        ('rfr', rfr)])

# %%
#clf.set_params(rfr__max_features=10, rfr__max_depth=20)
#clf.fit(X_train, y_train)

# %%
start_time = time.time()

param_grid = {'rfr__max_features': [10], 'rfr__max_depth': [20]}
model = grid_search.GridSearchCV(estimator = clf, param_grid = param_grid, n_jobs = -1, cv = 2, verbose = 20, scoring=RMSE)
model.fit(X_train, y_train)

print("--- Training: %s minutes ---" % round(((time.time() - start_time)/60),2))

# %%
print("Best parameters found by grid search:")
print(model.best_params_)
print("Best CV score:")
print(model.best_score_)

y_pred = model.predict(X_test)
pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('submission.csv',index=False)

# %%
df_all.dtypes
