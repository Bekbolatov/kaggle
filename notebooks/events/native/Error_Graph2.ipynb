# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a="""
[0]	eval-auc:0.571888	train-auc:0.570578
[1]	eval-auc:0.669116	train-auc:0.671742
[2]	eval-auc:0.720547	train-auc:0.728188
[3]	eval-auc:0.741805	train-auc:0.746803
[4]	eval-auc:0.767597	train-auc:0.773103
[5]	eval-auc:0.778377	train-auc:0.782986
[6]	eval-auc:0.785407	train-auc:0.791044
[7]	eval-auc:0.788040	train-auc:0.794346
[8]	eval-auc:0.794885	train-auc:0.802624
[9]	eval-auc:0.798660	train-auc:0.807729
[10]	eval-auc:0.807329	train-auc:0.819167
[11]	eval-auc:0.810920	train-auc:0.823677
[12]	eval-auc:0.819110	train-auc:0.832132
[13]	eval-auc:0.820978	train-auc:0.834964
[14]	eval-auc:0.817868	train-auc:0.832298
[15]	eval-auc:0.823983	train-auc:0.838039
[16]	eval-auc:0.827233	train-auc:0.842422
[17]	eval-auc:0.829689	train-auc:0.846540
[18]	eval-auc:0.831370	train-auc:0.849702
[19]	eval-auc:0.832082	train-auc:0.850469
[20]	eval-auc:0.835303	train-auc:0.854371
[21]	eval-auc:0.833663	train-auc:0.853799
[22]	eval-auc:0.833899	train-auc:0.853846
[23]	eval-auc:0.835625	train-auc:0.857114
[24]	eval-auc:0.839978	train-auc:0.861266
[25]	eval-auc:0.840748	train-auc:0.862461
[26]	eval-auc:0.841509	train-auc:0.863943
[27]	eval-auc:0.842579	train-auc:0.865011
[28]	eval-auc:0.844434	train-auc:0.866644
[29]	eval-auc:0.846302	train-auc:0.868351
[30]	eval-auc:0.847872	train-auc:0.869516
[31]	eval-auc:0.848143	train-auc:0.870502
[32]	eval-auc:0.849650	train-auc:0.871450
[33]	eval-auc:0.852369	train-auc:0.873044
[34]	eval-auc:0.854241	train-auc:0.875780
[35]	eval-auc:0.855179	train-auc:0.876370
[36]	eval-auc:0.856060	train-auc:0.877204
[37]	eval-auc:0.857198	train-auc:0.880156
[38]	eval-auc:0.858127	train-auc:0.880569
[39]	eval-auc:0.858670	train-auc:0.881253
[40]	eval-auc:0.859245	train-auc:0.882582
[41]	eval-auc:0.860025	train-auc:0.883376
[42]	eval-auc:0.860527	train-auc:0.884062
[43]	eval-auc:0.861210	train-auc:0.884648
[44]	eval-auc:0.862677	train-auc:0.886135
[45]	eval-auc:0.863119	train-auc:0.888211
[46]	eval-auc:0.864039	train-auc:0.889698
[47]	eval-auc:0.866251	train-auc:0.892327
[48]	eval-auc:0.866343	train-auc:0.892812
[49]	eval-auc:0.867532	train-auc:0.894115
[50]	eval-auc:0.868161	train-auc:0.894953
[51]	eval-auc:0.868677	train-auc:0.895795
[52]	eval-auc:0.869561	train-auc:0.896604
[53]	eval-auc:0.870744	train-auc:0.897685
[54]	eval-auc:0.870875	train-auc:0.898288
[55]	eval-auc:0.872273	train-auc:0.899960
[56]	eval-auc:0.872324	train-auc:0.900950
[57]	eval-auc:0.872719	train-auc:0.901812
[58]	eval-auc:0.873379	train-auc:0.902244
[59]	eval-auc:0.873774	train-auc:0.903060
[60]	eval-auc:0.874263	train-auc:0.903504
[61]	eval-auc:0.874900	train-auc:0.904355
[62]	eval-auc:0.875192	train-auc:0.905128
[63]	eval-auc:0.875229	train-auc:0.905836
[64]	eval-auc:0.875434	train-auc:0.906877
[65]	eval-auc:0.875694	train-auc:0.907149
[66]	eval-auc:0.875903	train-auc:0.907413
[67]	eval-auc:0.876154	train-auc:0.908050
[68]	eval-auc:0.876809	train-auc:0.908863
[69]	eval-auc:0.877196	train-auc:0.909129
[70]	eval-auc:0.877965	train-auc:0.909983
[71]	eval-auc:0.878306	train-auc:0.911014
[72]	eval-auc:0.878658	train-auc:0.912058
[73]	eval-auc:0.879480	train-auc:0.913474
[74]	eval-auc:0.880256	train-auc:0.914359
[75]	eval-auc:0.880748	train-auc:0.915150
[76]	eval-auc:0.880958	train-auc:0.916223
[77]	eval-auc:0.881704	train-auc:0.917060
[78]	eval-auc:0.882607	train-auc:0.918006
[79]	eval-auc:0.882961	train-auc:0.918365
[80]	eval-auc:0.883225	train-auc:0.919115
[81]	eval-auc:0.883436	train-auc:0.920067
[82]	eval-auc:0.884261	train-auc:0.920637
[83]	eval-auc:0.884263	train-auc:0.921400
[84]	eval-auc:0.884711	train-auc:0.922011
[85]	eval-auc:0.884968	train-auc:0.922526
[86]	eval-auc:0.885622	train-auc:0.923137
[87]	eval-auc:0.885768	train-auc:0.923867
[88]	eval-auc:0.886096	train-auc:0.924183
[89]	eval-auc:0.886311	train-auc:0.924420
[90]	eval-auc:0.886244	train-auc:0.925063
[91]	eval-auc:0.886509	train-auc:0.925689
[92]	eval-auc:0.886535	train-auc:0.926316
[93]	eval-auc:0.886599	train-auc:0.926623
[94]	eval-auc:0.886521	train-auc:0.927040
[95]	eval-auc:0.886263	train-auc:0.927633
[96]	eval-auc:0.886507	train-auc:0.927887
[97]	eval-auc:0.886924	train-auc:0.928083
[98]	eval-auc:0.887390	train-auc:0.928942
[99]	eval-auc:0.887190	train-auc:0.929243
[100]	eval-auc:0.887136	train-auc:0.929727
[101]	eval-auc:0.887021	train-auc:0.930446
[102]	eval-auc:0.887230	train-auc:0.930840
[103]	eval-auc:0.887457	train-auc:0.931489
[104]	eval-auc:0.887911	train-auc:0.931943
[105]	eval-auc:0.887682	train-auc:0.932392
[106]	eval-auc:0.887723	train-auc:0.932642
[107]	eval-auc:0.887644	train-auc:0.933252
[108]	eval-auc:0.888106	train-auc:0.933883
[109]	eval-auc:0.888805	train-auc:0.934456
[110]	eval-auc:0.888994	train-auc:0.934785
[111]	eval-auc:0.889256	train-auc:0.935552
[112]	eval-auc:0.889324	train-auc:0.936083
[113]	eval-auc:0.889406	train-auc:0.936468
[114]	eval-auc:0.889282	train-auc:0.936860
[115]	eval-auc:0.889466	train-auc:0.937192
[116]	eval-auc:0.890518	train-auc:0.938083
[117]	eval-auc:0.890591	train-auc:0.938432
[118]	eval-auc:0.890872	train-auc:0.938861
[119]	eval-auc:0.891068	train-auc:0.939099
[120]	eval-auc:0.891423	train-auc:0.939722
[121]	eval-auc:0.891317	train-auc:0.940024
[122]	eval-auc:0.891481	train-auc:0.940376
[123]	eval-auc:0.891499	train-auc:0.940828
[124]	eval-auc:0.891450	train-auc:0.941150
[125]	eval-auc:0.891330	train-auc:0.941501
[126]	eval-auc:0.891858	train-auc:0.942001
[127]	eval-auc:0.892030	train-auc:0.942414
[128]	eval-auc:0.892067	train-auc:0.942898
[129]	eval-auc:0.892335	train-auc:0.943133
[130]	eval-auc:0.892562	train-auc:0.943528
[131]	eval-auc:0.892808	train-auc:0.943750
[132]	eval-auc:0.892829	train-auc:0.943998
[133]	eval-auc:0.892916	train-auc:0.944266
[134]	eval-auc:0.892816	train-auc:0.944447
[135]	eval-auc:0.892990	train-auc:0.944814
[136]	eval-auc:0.893194	train-auc:0.944965
[137]	eval-auc:0.893152	train-auc:0.945269
[138]	eval-auc:0.893111	train-auc:0.945508
[139]	eval-auc:0.893161	train-auc:0.945914
[140]	eval-auc:0.893288	train-auc:0.946380
[141]	eval-auc:0.893300	train-auc:0.946632
[142]	eval-auc:0.893200	train-auc:0.947006
[143]	eval-auc:0.893308	train-auc:0.947240
[144]	eval-auc:0.893445	train-auc:0.947604
[145]	eval-auc:0.893497	train-auc:0.947951
[146]	eval-auc:0.893292	train-auc:0.948222
[147]	eval-auc:0.893233	train-auc:0.948467
[148]	eval-auc:0.893861	train-auc:0.948951
[149]	eval-auc:0.893689	train-auc:0.949246
[150]	eval-auc:0.893935	train-auc:0.949680
[151]	eval-auc:0.893972	train-auc:0.949965
[152]	eval-auc:0.894004	train-auc:0.950185
[153]	eval-auc:0.894187	train-auc:0.950553
[154]	eval-auc:0.893750	train-auc:0.950953
[155]	eval-auc:0.893732	train-auc:0.951201
[156]	eval-auc:0.893897	train-auc:0.951652
[157]	eval-auc:0.893918	train-auc:0.951860
[158]	eval-auc:0.893828	train-auc:0.952108
[159]	eval-auc:0.893675	train-auc:0.952415
[160]	eval-auc:0.893751	train-auc:0.952944
[161]	eval-auc:0.893894	train-auc:0.953223
[162]	eval-auc:0.893729	train-auc:0.953394
[163]	eval-auc:0.893642	train-auc:0.953742
[164]	eval-auc:0.893561	train-auc:0.953875
[165]	eval-auc:0.893711	train-auc:0.954380
[166]	eval-auc:0.893593	train-auc:0.954636
[167]	eval-auc:0.893920	train-auc:0.954878
[168]	eval-auc:0.893897	train-auc:0.955115
[169]	eval-auc:0.893894	train-auc:0.955342
[170]	eval-auc:0.894115	train-auc:0.955590
[171]	eval-auc:0.894206	train-auc:0.955799
[172]	eval-auc:0.894186	train-auc:0.956109
[173]	eval-auc:0.894239	train-auc:0.956412
[174]	eval-auc:0.894125	train-auc:0.956609
[175]	eval-auc:0.894074	train-auc:0.956821
[176]	eval-auc:0.894282	train-auc:0.957114
[177]	eval-auc:0.894540	train-auc:0.957312
[178]	eval-auc:0.894758	train-auc:0.957439
[179]	eval-auc:0.894980	train-auc:0.957656
[180]	eval-auc:0.895149	train-auc:0.957829
[181]	eval-auc:0.895524	train-auc:0.958000
[182]	eval-auc:0.895656	train-auc:0.958339
[183]	eval-auc:0.895484	train-auc:0.958565
[184]	eval-auc:0.895622	train-auc:0.958679
[185]	eval-auc:0.895521	train-auc:0.958892
[186]	eval-auc:0.895520	train-auc:0.959173
[187]	eval-auc:0.895474	train-auc:0.959405
[188]	eval-auc:0.895519	train-auc:0.959580
[189]	eval-auc:0.895513	train-auc:0.959699
[190]	eval-auc:0.895437	train-auc:0.959934
[191]	eval-auc:0.895376	train-auc:0.960204
[192]	eval-auc:0.895352	train-auc:0.960376
[193]	eval-auc:0.895540	train-auc:0.960603
[194]	eval-auc:0.895805	train-auc:0.960768
[195]	eval-auc:0.895863	train-auc:0.961053
[196]	eval-auc:0.895709	train-auc:0.961299
[197]	eval-auc:0.895936	train-auc:0.961636
[198]	eval-auc:0.895786	train-auc:0.961858
[199]	eval-auc:0.895897	train-auc:0.961990
[200]	eval-auc:0.896047	train-auc:0.962163
[201]	eval-auc:0.895740	train-auc:0.962506
[202]	eval-auc:0.895837	train-auc:0.962638
[203]	eval-auc:0.895810	train-auc:0.962903
[204]	eval-auc:0.895685	train-auc:0.962987
[205]	eval-auc:0.895814	train-auc:0.963103
[206]	eval-auc:0.895840	train-auc:0.963400
[207]	eval-auc:0.895851	train-auc:0.963501
[208]	eval-auc:0.896012	train-auc:0.963733
[209]	eval-auc:0.896054	train-auc:0.963886
[210]	eval-auc:0.896073	train-auc:0.964085
[211]	eval-auc:0.895871	train-auc:0.964297
[212]	eval-auc:0.895851	train-auc:0.964394
[213]	eval-auc:0.896042	train-auc:0.964541
[214]	eval-auc:0.896196	train-auc:0.964757
[215]	eval-auc:0.896464	train-auc:0.965033
[216]	eval-auc:0.896395	train-auc:0.965148
[217]	eval-auc:0.896050	train-auc:0.965273
[218]	eval-auc:0.896063	train-auc:0.965446
[219]	eval-auc:0.896424	train-auc:0.965759
[220]	eval-auc:0.896328	train-auc:0.965854
[221]	eval-auc:0.897140	train-auc:0.966326
[222]	eval-auc:0.897156	train-auc:0.966463
[223]	eval-auc:0.897179	train-auc:0.966586
[224]	eval-auc:0.897380	train-auc:0.966922
[225]	eval-auc:0.897622	train-auc:0.967142
[226]	eval-auc:0.897773	train-auc:0.967291
[227]	eval-auc:0.897684	train-auc:0.967559
[228]	eval-auc:0.897578	train-auc:0.967651
[229]	eval-auc:0.897894	train-auc:0.967914
[230]	eval-auc:0.898068	train-auc:0.968007
[231]	eval-auc:0.898125	train-auc:0.968162
[232]	eval-auc:0.898154	train-auc:0.968299
[233]	eval-auc:0.898093	train-auc:0.968411
[234]	eval-auc:0.898123	train-auc:0.968552
[235]	eval-auc:0.897936	train-auc:0.968676
[236]	eval-auc:0.898019	train-auc:0.968858
[237]	eval-auc:0.898189	train-auc:0.969186
[238]	eval-auc:0.898098	train-auc:0.969449
[239]	eval-auc:0.897973	train-auc:0.969595
[240]	eval-auc:0.898071	train-auc:0.969940
[241]	eval-auc:0.897730	train-auc:0.970134
[242]	eval-auc:0.898073	train-auc:0.970372
[243]	eval-auc:0.898212	train-auc:0.970487
[244]	eval-auc:0.898309	train-auc:0.970618
[245]	eval-auc:0.898417	train-auc:0.970749
[246]	eval-auc:0.898539	train-auc:0.970923
[247]	eval-auc:0.898833	train-auc:0.971099
[248]	eval-auc:0.898907	train-auc:0.971210
[249]	eval-auc:0.898861	train-auc:0.971314
[250]	eval-auc:0.898958	train-auc:0.971500
[251]	eval-auc:0.898984	train-auc:0.971618
[252]	eval-auc:0.898921	train-auc:0.971810
[253]	eval-auc:0.898972	train-auc:0.972046
[254]	eval-auc:0.899030	train-auc:0.972222
[255]	eval-auc:0.898972	train-auc:0.972374
[256]	eval-auc:0.898977	train-auc:0.972486
[257]	eval-auc:0.899087	train-auc:0.972647
[258]	eval-auc:0.899028	train-auc:0.972833
[259]	eval-auc:0.899203	train-auc:0.973048
[260]	eval-auc:0.899238	train-auc:0.973158
[261]	eval-auc:0.899727	train-auc:0.973397
[262]	eval-auc:0.899651	train-auc:0.973569
[263]	eval-auc:0.899717	train-auc:0.973659
[264]	eval-auc:0.899666	train-auc:0.973771
[265]	eval-auc:0.899543	train-auc:0.973970
[266]	eval-auc:0.899701	train-auc:0.974115
[267]	eval-auc:0.899578	train-auc:0.974262
[268]	eval-auc:0.899715	train-auc:0.974368
[269]	eval-auc:0.899843	train-auc:0.974493
[270]	eval-auc:0.899879	train-auc:0.974752
[271]	eval-auc:0.900335	train-auc:0.974992
[272]	eval-auc:0.900338	train-auc:0.975083
[273]	eval-auc:0.900352	train-auc:0.975213
[274]	eval-auc:0.900429	train-auc:0.975323
[275]	eval-auc:0.900465	train-auc:0.975435
[276]	eval-auc:0.900440	train-auc:0.975568
[277]	eval-auc:0.900434	train-auc:0.975679
[278]	eval-auc:0.900530	train-auc:0.975799
[279]	eval-auc:0.900762	train-auc:0.975946
[280]	eval-auc:0.900667	train-auc:0.976072
[281]	eval-auc:0.900692	train-auc:0.976155
[282]	eval-auc:0.900726	train-auc:0.976308
[283]	eval-auc:0.900523	train-auc:0.976452
[284]	eval-auc:0.900558	train-auc:0.976555
[285]	eval-auc:0.900378	train-auc:0.976723
[286]	eval-auc:0.900316	train-auc:0.976809
[287]	eval-auc:0.900340	train-auc:0.976941
[288]	eval-auc:0.900353	train-auc:0.977043
[289]	eval-auc:0.900136	train-auc:0.977191
[290]	eval-auc:0.900218	train-auc:0.977278
[291]	eval-auc:0.900299	train-auc:0.977415
[292]	eval-auc:0.900274	train-auc:0.977528
[293]	eval-auc:0.900185	train-auc:0.977592
[294]	eval-auc:0.899921	train-auc:0.977673
[295]	eval-auc:0.900248	train-auc:0.977865
[296]	eval-auc:0.900167	train-auc:0.977958
[297]	eval-auc:0.900137	train-auc:0.977994
[298]	eval-auc:0.900039	train-auc:0.978115
[299]	eval-auc:0.900237	train-auc:0.978182
"""

# %%
anp = pd.DataFrame(np.array( # max depth [5], eta 1.0, gamma 1.0, colsample_bytree 0.3, subsample: 0.9
        [[float(s.split(':')[1]) for s in ss.split()[1:3]] for ss in a.splitlines() if ss]
        ), columns=['cv', 'train'])

# %%
plt.plot(anp)

# %%
anp = pd.DataFrame(np.array([[ float(s) for s in ss.split()[2:4]] for ss in a.splitlines() if ss]), columns=['train', 'cv'])
#anp_2_015_035 = anp
