# %%
# %matplotlib inline

import matplotlib
import numpy as np
import numpy.random as r
import matplotlib.pyplot as plt

# %%
N = 10000

# %%
nums = r.rand(2, N)
plt.scatter(nums[0], nums[1], s=1)

# %%
nums = r.randn(2, N)
plt.scatter(nums[0], nums[1], s=1)

# %%
r.dirichlet(np.array([0.1, 0.1]), 2)
# Out:
# array([[  9.98480196e-01,   1.51980448e-03],
#        [  3.88201488e-05,   9.99961180e-01]])
