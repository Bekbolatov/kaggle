# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

matplotlib.rcParams['figure.figsize'] = (20, 9)

# %%
d = pd.DataFrame.from_csv('/Users/rbekbolatov/data/avvo/call_durations.csv')

# %%
d[d['dd']==202]  # 148,176
# 2015-11-26
# 2015-12-24
# Out:
#              dd  call_duratn_second_cnt  cnt
# call_date
# 2016-01-19  202                       1   53
# 2016-01-19  202                       2   30
# 2016-01-19  202                       3   61
# 2016-01-19  202                       4   78
# 2016-01-19  202                       5   92
# 2016-01-19  202                       6  102
# 2016-01-19  202                       7   89
# 2016-01-19  202                       8   96
# 2016-01-19  202                       9   82
# 2016-01-19  202                      10   76
# 2016-01-19  202                      11   75
# 2016-01-19  202                      12   67
# 2016-01-19  202                      13   81
# 2016-01-19  202                      14   53
# 2016-01-19  202                      15   58
# 2016-01-19  202                      16   53
# 2016-01-19  202                      17   57
# 2016-01-19  202                      18   52
# 2016-01-19  202                      19   52
# 2016-01-19  202                      20   43
# ...

# %%
plt.plot(d[d['dd']==41]['cnt'])
plt.plot(d[d['dd']==47]['cnt'])
plt.plot(d[d['dd']==20]['cnt'])
plt.plot(d[d['dd']==202]['cnt'])

# %%
#cm = plt.cm.get_cmap('RdYlBu')
plt.scatter(np.array(d['dd']), np.array(d['call_duratn_second_cnt']), c=d['cnt'], cmap=cm.Reds, marker="o", linewidths=0, vmin=0, vmax=90)
plt.xlim(-1, 216)
plt.ylim(-1, 61)
plt.title('Call duration frequencies (up to 60sec)')
plt.xlabel('Days: 2015-07-01 through 2016-02-01')
plt.ylabel('Duration (seconds)')

# %%
d.groupby('dd').sum()['cnt'].plot()

# %%
d.groupby('dd').sum()
# Out:
#      call_duratn_second_cnt   cnt
# dd
# 0                      1830  2277
# 1                      1830  2212
# 2                      1830  1855
# 3                      1801   318
# 4                      1752   381
# 5                      1830  3090
# 6                      1830  2606
# 7                      1830  2490
# 8                      1830  2393
# 9                      1830  2374
# 10                     1830   677
# 11                     1773   392
# 12                     1830  2989
# 13                     1830  2676
# 14                     1830  2440
# 15                     1830  2146
# 16                     1830  2382
# 17                     1830   708
# 18                     1724   390
# 19                     1830  3189
# 20                     1830  2629
# 21                     1830  2492
# 22                     1830  2542
# 23                     1830  2453
# 24                     1830   724
# 25                     1830   504
# ...
