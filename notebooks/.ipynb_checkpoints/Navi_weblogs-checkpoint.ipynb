# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## contact_impression

# %%
a = pd.DataFrame()
for i in range(2):
    try:
        a = a.append(pd.read_csv('/Users/rbekbolatov/tmp/Navi_compare/p' + str(i) + '.csv'), ignore_index=True)
    except:
        pass
    
a = a.rename(columns={col:col[4:] for col in a.columns})

# %%
contacts = a.pivot_table('cnt', index=['event_date', 'contact_type'], columns=['system', 'filter'], fill_value=0)

# %%
contacts['navi', 'total'] = contacts['navi', 'blocked'] + contacts['navi', 'passed']
contacts['prod', 'total'] = contacts['prod', 'blocked'] + contacts['prod', 'passed']

contacts['change_abs', 'passed'] = contacts['navi', 'passed'] - contacts['prod', 'passed']
contacts['change_abs', 'blocked'] = contacts['navi', 'blocked'] - contacts['prod', 'blocked']
contacts['change_abs', 'total'] = contacts['navi', 'total'] - contacts['prod', 'total']

contacts['change', 'passed'] = ["{0:.2f}%".format(val * 100)  for val in (contacts['change_abs', 'passed'] / contacts['prod', 'passed'])]
contacts['change', 'blocked'] = ["{0:.2f}%".format(val * 100)  for val in (contacts['change_abs', 'blocked'] / contacts['prod', 'blocked'])]
contacts['change', 'total'] = ["{0:.2f}%".format(val * 100)  for val in (contacts['change_abs', 'total'] / contacts['prod', 'total'])]

contacts = contacts.sort_index(axis=1, ascending=False)
contacts = contacts.sort_index(axis=0, ascending=True)

contact_impressions = contacts

# %%
contact_impressions
# Out:
# system                   prod                 navi                change_abs  \
# filter                  total passed blocked total passed blocked      total
# event_date contact_type
# 2015-09-23 email         1787   1569     218  2069   1468     601        282
#            phone         5075   4887     188  5075   4904     171          0
#            website       8333   8215     118  8282   8006     276        -51
# 2015-09-24 email         1032   1017      15  1264   1030     234        232
#            phone         4790   4526     264  4790   4554     236          0
#            website       7924   7810     114  7792   7550     242       -132
#
# system                                  change
# filter                  passed blocked   total  passed   blocked
# event_date contact_type
# 2015-09-23 email          -101     383  15.78%  -6.44%   175.69%
#            phone            17     -17   0.00%   0.35%    -9.04%
#            website        -209     158  -0.61%  -2.54%   133.90%
# 2015-09-24 email            13     219  22.48%   1.28%  1460.00%
#            phone            28     -28   0.00%   0.62%   -10.61%
#            website        -260     128  -1.67%  -3.33%   112.28%

# %% [markdown]
# ## professional_impression

# %%
a = pd.DataFrame()
for i in range(2):
    try:
        a = a.append(pd.read_csv('/Users/rbekbolatov/tmp/Navi_compare/pr' + str(i) + '.csv'), ignore_index=True)
    except:
        pass
    
a = a.rename(columns={col:col[4:] for col in a.columns})

# %%
contacts = a.pivot_table('cnt', index=['event_date', 'category'], columns=['system', 'filter'], fill_value=0)

# %%
contacts['navi', 'total'] = contacts['navi', 'blocked'] + contacts['navi', 'passed']
contacts['prod', 'total'] = contacts['prod', 'blocked'] + contacts['prod', 'passed']

contacts['change_abs', 'passed'] = contacts['navi', 'passed'] - contacts['prod', 'passed']
contacts['change_abs', 'blocked'] = contacts['navi', 'blocked'] - contacts['prod', 'blocked']
contacts['change_abs', 'total'] = contacts['navi', 'total'] - contacts['prod', 'total']

contacts['change', 'passed'] = ["{0:.2f}%".format(val * 100)  for val in (contacts['change_abs', 'passed'] / contacts['prod', 'passed'])]
contacts['change', 'blocked'] = ["{0:.2f}%".format(val * 100)  for val in (contacts['change_abs', 'blocked'] / contacts['prod', 'blocked'])]
contacts['change', 'total'] = ["{0:.2f}%".format(val * 100)  for val in (contacts['change_abs', 'total'] / contacts['prod', 'total'])]

contacts = contacts.sort_index(axis=1, ascending=False)
contacts = contacts.sort_index(axis=0, ascending=True)

professional_impressions = contacts

# %%
professional_impressions
# Out:
# system                                 prod                    navi          \
# filter                                total  passed blocked   total  passed
# event_date category
# 2015-09-23 answers                   974814  861427  113387  928225  793406
#            display_medium_rectangle     102      92      10      66      64
#            global_search                 80      62      18      86      63
#            lawyer_directory          535306  448230   87076  506252  425978
#            legal_guides               24136   22640    1496   23629   23005
#            profile                   321238  205725  115513  300298  213481
#            sponsored_listing            550     452      98     310     267
#            top_contributors             456     402      54     462     402
# 2015-09-24 answers                   979224  856443  122781  945182  779315
#            display_medium_rectangle      85      79       6      59      51
#            global_search                137     107      30     163     131
#            lawyer_directory          545384  440812  104572  530009  423034
#            legal_guides               22836   21612    1224   22553   21945
#            profile                   326536  196207  130329  293470  205745
#            sponsored_listing            369     320      49     254     203
#            top_contributors             228     144      84     234      96
#
# system                                      change_abs                 \
# filter                              blocked      total passed blocked
# event_date category
# 2015-09-23 answers                   134819     -46589 -68021   21432
#            display_medium_rectangle       2        -36    -28      -8
#            global_search                 23          6      1       5
#            lawyer_directory           80274     -29054 -22252   -6802
#            legal_guides                 624       -507    365    -872
#            profile                    86817     -20940   7756  -28696
#            sponsored_listing             43       -240   -185     -55
#            top_contributors              60          6      0       6
# 2015-09-24 answers                   165867     -34042 -77128   43086
#            display_medium_rectangle       8        -26    -28       2
#            global_search                 32         26     24       2
#            lawyer_directory          106975     -15375 -17778    2403
#            legal_guides                 608       -283    333    -616
#            profile                    87725     -33066   9538  -42604
#            sponsored_listing             51       -115   -117       2
#            top_contributors             138          6    -48      54
#
# system                                change
# filter                                 total   passed  blocked
# event_date category
# 2015-09-23 answers                    -4.78%   -7.90%   18.90%
#            display_medium_rectangle  -35.29%  -30.43%  -80.00%
#            global_search               7.50%    1.61%   27.78%
#            lawyer_directory           -5.43%   -4.96%   -7.81%
#            legal_guides               -2.10%    1.61%  -58.29%
#            profile                    -6.52%    3.77%  -24.84%
#            sponsored_listing         -43.64%  -40.93%  -56.12%
#            top_contributors            1.32%    0.00%   11.11%
# 2015-09-24 answers                    -3.48%   -9.01%   35.09%
#            display_medium_rectangle  -30.59%  -35.44%   33.33%
#            global_search              18.98%   22.43%    6.67%
#            lawyer_directory           -2.82%   -4.03%    2.30%
#            legal_guides               -1.24%    1.54%  -50.33%
#            profile                   -10.13%    4.86%  -32.69%
#            sponsored_listing         -31.17%  -36.56%    4.08%
#            top_contributors            2.63%  -33.33%   64.29%
